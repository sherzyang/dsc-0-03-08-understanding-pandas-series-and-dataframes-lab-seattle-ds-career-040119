# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Read the turnstile text document 
turnstile_df = pd.read_csv('turnstile_180901.txt')

#See the length of the dataframe 
print(len(df))

#See the first 5 rows of the dataframe 
turnstile_df.head()

#See the columns of the dataframe 
turnstile_df.columns

#change the columns of lower case 
turnstile_df.columns = map(str.lower, turnstile_df.columns)
turnstile_df = turnstile_df.head()
turnstile_df
# Out:
# 197625
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#change the index to be the line names 
turnstile_df.set_index('linename', drop=True, append=False, inplace=False, verify_integrity=False)
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [raw]
# # Painstakingly change the index back

# %%
# # Change the index from linename to len(turnstile_df.index)
# length_of_rows = len(turnstile_df.index)
# type(length_of_rows)
# new_index_range = range(0,length_of_rows)
# new_index = list(new_index_range)
# new_index
#turnstile_df.insert(length_of_rows,"index",new_index,True)
#turnstile_df.set_index(new_index, drop=True, append=False, inplace=False, verify_integrity=False)
#turnstile_df.drop('index', axis =1)


#another way to do it 
turnstile_df.reindex()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
all_turnstile_df = pd.read_csv('turnstile_180901.txt')

#get the linename series 
linename_series = all_turnstile_df.T.loc['LINENAME']
linename_series.head()

count_of_lines = []
for linename in linename_series: 
    temp = len(linename)
    count_of_lines.append(temp)

length = len(all_turnstile_df)
all_turnstile_df_new = all_turnstile_df.insert(length,"Num_lines",count_of_lines,True)
all_turnstile_df_new.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-08943439602d> in <module>
#      12
#      13 length = len(all_turnstile_df)
# ---> 14 all_turnstile_df_new = all_turnstile_df.insert(length,"Num_lines",count_of_lines,True)
#      15 all_turnstile_df_new.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3220         value = self._sanitize_column(column, value, broadcast=False)
#    3221         self._data.insert(loc, column, value,
# -> 3222                           allow_duplicates=allow_duplicates)
#    3223
#    3224     def assign(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4362             self._blknos = np.append(self._blknos, len(self.blocks))
#    4363         else:
# -> 4364             self._blklocs = np.insert(self._blklocs, loc, 0)
#    4365             self._blknos = np.insert(self._blknos, loc, len(self.blocks))
#    4366
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in insert(arr, obj, values, axis)
#    4415             raise IndexError(
#    4416                 "index %i is out of bounds for axis %i with "
# -> 4417                 "size %i" % (obj, axis, N))
#    4418         if (index < 0):
#    4419             index += N
#
# IndexError: index 197625 is out of bounds for axis 0 with size 11

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
